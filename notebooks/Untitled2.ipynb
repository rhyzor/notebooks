# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
np.random.rand(10,1)
# Out:
# array([[0.20908131],
#        [0.95314649],
#        [0.0281735 ],
#        [0.38829953],
#        [0.55208921],
#        [0.26175067],
#        [0.10583158],
#        [0.36680779],
#        [0.53962793],
#        [0.80897333]])

# %%
np.random.randn(2, 1)
# Out:
# array([[-0.07326872],
#        [-1.12721815]])

# %%
rng = np.random.default_rng(seed=0)
x = rng.standard_normal((100,1))
y = 1 + 5*x + rng.standard_normal((100,1 ))

# %%
plt.scatter(x,y,s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show();
